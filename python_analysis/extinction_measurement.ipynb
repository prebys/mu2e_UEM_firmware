# %%
import re

from matplotlib import pyplot as plt

from socketudp.hex_check import HexCheck
# %load_ext autoreload
# %autoreload 2

import numpy as np


from extinction_plots import plot_normalized_histogram
from extinction_functions import simulate_delta_train, get_delta_trains_from_hex, \
    get_three_fold_coincidence_points, symmetric_mod, \
    combine_periods, deep_reload, get_delta_trains_per_event_from_hex

import hex_check as hc_mod
from socketudp.hex_check_classes import NewEvent, PeakArea

# Force a clean reload order: deps first, then dependents
deep_reload("hex_check")

desired_file_path = None
# desired_file_path = "data_20251216_202608.dat"  # set to a value if you wish to specify a specific file, overrides setting in hex_check_config.py

# Rebuild the object so it picks up new config/code
hc = hc_mod.build_hex_check(plot=False, new=True, desired_file_path=desired_file_path)



# np_seterr(all='raise')
# Out:
# Reloaded hex_check_config
# Reloaded hex_check_classes
#
# Reloaded hex_check
# ℹ️ℹ️ Info: Multiple .dat files found in the current directory. Picking this one (data_20260203_101900.dat) ℹ️ℹ️
# Using input file data_20260203_101900.dat
# # Peakfinding Length: 300000000
# # Number of subevents: 99
# # Raw Data Length: 0
# # Peakfinding Threshold: -200
# # Peak height event count: 200
# # Peak area event count: 600
# # FPGA Test Mode: 0
# # ADC 0 1 2 3 Enabled: (True, True, True, True)
# # top_fmc228_pcie_v27.1.bit
# Found 183 events in the file.
# Parsing NewEvent #1, data length 60232.
# data_str starts with ffffff11000649edcff0
# Found timestamp: 2026-02-03 10:20:05.007598-06:00, skipping ffffff11000649edcff0d4ee
# Event 3364738-1 has timestamp 2026-02-03 10:20:05.007598-06:00
# Event 3364738-1 has 99 sub-events.
# Parsing NewEvent #2, data length 60232.
# data_str starts with ffffff11000649edd1a8
# Found timestamp: 2026-02-03 10:20:33.796895-06:00, skipping ffffff11000649edd1a81f1f
# Event 3364837-2 has timestamp 2026-02-03 10:20:33.796895-06:00
# Event 3364837-2 has 99 sub-events.
# Parsing NewEvent #3, data length 60232.
# data_str starts with ffffff11000649edd384
# Found timestamp: 2026-02-03 10:21:04.989671-06:00, skipping ffffff11000649edd38415e7
# Event 3364936-3 has timestamp 2026-02-03 10:21:04.989671-06:00
# Event 3364936-3 has 99 sub-events.
# Parsing NewEvent #4, data length 60232.
# data_str starts with ffffff11000649edd53b
# Found timestamp: 2026-02-03 10:21:33.789780-06:00, skipping ffffff11000649edd53b8a54
# Event 3365035-4 has timestamp 2026-02-03 10:21:33.789780-06:00
# Event 3365035-4 has 99 sub-events.
# Parsing NewEvent #5, data length 60296.
# data_str starts with ffffff11000649edd8cf
# Found timestamp: 2026-02-03 10:22:33.798263-06:00, skipping ffffff11000649edd8cf3277
# Event 3365134-5 has timestamp 2026-02-03 10:22:33.798263-06:00
# Event 3365134-5 has 99 sub-events.
# Parsing NewEvent #6, data length 60232.
# data_str starts with ffffff11000649ede1bf
# Found timestamp: 2026-02-03 10:25:03.756262-06:00, skipping ffffff11000649ede1bf5fe6
# Event 3365233-6 has timestamp 2026-02-03 10:25:03.756262-06:00
# Event 3365233-6 has 99 sub-events.
# Parsing NewEvent #7, data length 60232.
# data_str starts with ffffff11000649ede389
# Found timestamp: 2026-02-03 10:25:33.749820-06:00, skipping ffffff11000649ede3890a3c
# Event 3365332-7 has timestamp 2026-02-03 10:25:33.749820-06:00
# Event 3365332-7 has 99 sub-events.
# Parsing NewEvent #8, data length 60232.
# data_str starts with ffffff11000649ede8e6
# Found timestamp: 2026-02-03 10:27:03.737915-06:00, skipping ffffff11000649ede8e6263b
# Event 3365431-8 has timestamp 2026-02-03 10:27:03.737915-06:00
# Event 3365431-8 has 99 sub-events.
# Parsing NewEvent #9, data length 60232.
# data_str starts with ffffff11000649edec79
# Found timestamp: 2026-02-03 10:28:03.739183-06:00, skipping ffffff11000649edec79b22f
# Event 3365530-9 has timestamp 2026-02-03 10:28:03.739183-06:00
# Event 3365530-9 has 99 sub-events.
# Parsing NewEvent #10, data length 60232.
# data_str starts with ffffff11000649edfac7
# Found timestamp: 2026-02-03 10:32:03.701352-06:00, skipping ffffff11000649edfac73a68
# Event 3365629-10 has timestamp 2026-02-03 10:32:03.701352-06:00
# Event 3365629-10 has 99 sub-events.
# Parsing NewEvent #11, data length 60232.
# data_str starts with ffffff11000649edfc90
# Found timestamp: 2026-02-03 10:32:33.693564-06:00, skipping ffffff11000649edfc90df7c
# Event 3365728-11 has timestamp 2026-02-03 10:32:33.693564-06:00
# Event 3365728-11 has 99 sub-events.
# Parsing NewEvent #12, data length 60296.
# data_str starts with ffffff11000649ee0024
# Found timestamp: 2026-02-03 10:33:33.694930-06:00, skipping ffffff11000649ee00246bd2
# Event 3365827-12 has timestamp 2026-02-03 10:33:33.694930-06:00
# Event 3365827-12 has 99 sub-events.
# Parsing NewEvent #13, data length 60232.
# data_str starts with ffffff11000649ee074b
# Found timestamp: 2026-02-03 10:35:33.668175-06:00, skipping ffffff11000649ee074b114f
# Event 3365926-13 has timestamp 2026-02-03 10:35:33.668175-06:00
# Event 3365926-13 has 99 sub-events.
# Parsing NewEvent #14, data length 60232.
# data_str starts with ffffff11000649ee0ade
# Found timestamp: 2026-02-03 10:36:33.647496-06:00, skipping ffffff11000649ee0ade4788
# Event 3366025-14 has timestamp 2026-02-03 10:36:33.647496-06:00
# Event 3366025-14 has 99 sub-events.
# Parsing NewEvent #15, data length 60232.
# data_str starts with ffffff11000649ee0e71
# Found timestamp: 2026-02-03 10:37:33.623252-06:00, skipping ffffff11000649ee0e716fd4
# Event 3366124-15 has timestamp 2026-02-03 10:37:33.623252-06:00
# Event 3366124-15 has 99 sub-events.
# Parsing NewEvent #16, data length 60232.
# data_str starts with ffffff11000649ee103b
# Found timestamp: 2026-02-03 10:38:03.610949-06:00, skipping ffffff11000649ee103b0345
# Event 3366223-16 has timestamp 2026-02-03 10:38:03.610949-06:00
# Event 3366223-16 has 99 sub-events.
# Parsing NewEvent #17, data length 60232.
# data_str starts with ffffff11000649ee1204
# Found timestamp: 2026-02-03 10:38:33.598137-06:00, skipping ffffff11000649ee120494b9
# Event 3366322-17 has timestamp 2026-02-03 10:38:33.598137-06:00
# Event 3366322-17 has 99 sub-events.
# Parsing NewEvent #18, data length 60296.
# data_str starts with ffffff11000649ee1e87
# Found timestamp: 2026-02-03 10:42:03.515853-06:00, skipping ffffff11000649ee1e87abcd
# Event 3366421-18 has timestamp 2026-02-03 10:42:03.515853-06:00
# Event 3366421-18 has 99 sub-events.
# Parsing NewEvent #19, data length 60232.
# data_str starts with ffffff11000649ee25d2
# Found timestamp: 2026-02-03 10:44:05.857315-06:00, skipping ffffff11000649ee25d27423
# Event 3366520-19 has timestamp 2026-02-03 10:44:05.857315-06:00
# Event 3366520-19 has 99 sub-events.
# Parsing NewEvent #20, data length 60232.
# data_str starts with ffffff11000649ee3231
# Found timestamp: 2026-02-03 10:47:33.398996-06:00, skipping ffffff11000649ee323149d4
# Event 3366619-20 has timestamp 2026-02-03 10:47:33.398996-06:00
# Event 3366619-20 has 99 sub-events.
# Parsing NewEvent #21, data length 60296.
# data_str starts with ffffff11000649ee33fa
# Found timestamp: 2026-02-03 10:48:03.393369-06:00, skipping ffffff11000649ee33faf759
# Event 3366718-21 has timestamp 2026-02-03 10:48:03.393369-06:00
# Event 3366718-21 has 99 sub-events.
# Parsing NewEvent #22, data length 60232.
# data_str starts with ffffff11000649ee3b22
# Found timestamp: 2026-02-03 10:50:03.433490-06:00, skipping ffffff11000649ee3b22a212
# Event 3366817-22 has timestamp 2026-02-03 10:50:03.433490-06:00
# Event 3366817-22 has 99 sub-events.
# Parsing NewEvent #23, data length 60232.
# data_str starts with ffffff11000649ee47a5
# Found timestamp: 2026-02-03 10:53:33.358472-06:00, skipping ffffff11000649ee47a5d588
# Event 3366916-23 has timestamp 2026-02-03 10:53:33.358472-06:00
# Event 3366916-23 has 99 sub-events.
# Parsing NewEvent #24, data length 60232.
# data_str starts with ffffff11000649ee4b38
# Found timestamp: 2026-02-03 10:54:33.322526-06:00, skipping ffffff11000649ee4b38d01e
# Event 3367015-24 has timestamp 2026-02-03 10:54:33.322526-06:00
# Event 3367015-24 has 99 sub-events.
# Parsing NewEvent #25, data length 60232.
# data_str starts with ffffff11000649ee4ecb
# Found timestamp: 2026-02-03 10:55:33.285480-06:00, skipping ffffff11000649ee4ecbc668
# Event 3367114-25 has timestamp 2026-02-03 10:55:33.285480-06:00
# Event 3367114-25 has 99 sub-events.
# Parsing NewEvent #26, data length 60232.
# data_str starts with ffffff11000649ee525e
# Found timestamp: 2026-02-03 10:56:33.248288-06:00, skipping ffffff11000649ee525ebc20
# Event 3367213-26 has timestamp 2026-02-03 10:56:33.248288-06:00
# Event 3367213-26 has 99 sub-events.
# Parsing NewEvent #27, data length 60232.
# data_str starts with ffffff11000649ee5428
# Found timestamp: 2026-02-03 10:57:03.230820-06:00, skipping ffffff11000649ee54283b64
# Event 3367312-27 has timestamp 2026-02-03 10:57:03.230820-06:00
# Event 3367312-27 has 99 sub-events.
# Parsing NewEvent #28, data length 60232.
# data_str starts with ffffff11000649ee57bb
# Found timestamp: 2026-02-03 10:58:03.195866-06:00, skipping ffffff11000649ee57bb39da
# Event 3367411-28 has timestamp 2026-02-03 10:58:03.195866-06:00
# Event 3367411-28 has 99 sub-events.
# Parsing NewEvent #29, data length 60232.
# data_str starts with ffffff11000649ee5b4e
# Found timestamp: 2026-02-03 10:59:03.159906-06:00, skipping ffffff11000649ee5b4e3462
# Event 3367510-29 has timestamp 2026-02-03 10:59:03.159906-06:00
# Event 3367510-29 has 99 sub-events.
# Parsing NewEvent #30, data length 60232.
# data_str starts with ffffff11000649ee5ef3
# Found timestamp: 2026-02-03 11:00:04.323801-06:00, skipping ffffff11000649ee5ef37dd9
# Event 3367609-30 has timestamp 2026-02-03 11:00:04.323801-06:00
# Event 3367609-30 has 99 sub-events.
# Parsing NewEvent #31, data length 60232.
# data_str starts with ffffff11000649ee60aa
# Found timestamp: 2026-02-03 11:00:33.107559-06:00, skipping ffffff11000649ee60aab267
# Event 3367708-31 has timestamp 2026-02-03 11:00:33.107559-06:00
# Event 3367708-31 has 99 sub-events.
# Parsing NewEvent #32, data length 60296.
# data_str starts with ffffff11000649ee699a
# Found timestamp: 2026-02-03 11:03:03.042233-06:00, skipping ffffff11000649ee699a84b9
# Event 3367807-32 has timestamp 2026-02-03 11:03:03.042233-06:00
# Event 3367807-32 has 99 sub-events.
# Parsing NewEvent #33, data length 60296.
# data_str starts with ffffff11000649ee6ef7
# Found timestamp: 2026-02-03 11:04:32.999197-06:00, skipping ffffff11000649ee6ef7271d
# Event 3367906-33 has timestamp 2026-02-03 11:04:32.999197-06:00
# Event 3367906-33 has 99 sub-events.
# Parsing NewEvent #34, data length 60296.
# data_str starts with ffffff11000649ee70c0
# Found timestamp: 2026-02-03 11:05:02.985213-06:00, skipping ffffff11000649ee70c0b3fd
# Event 3368005-34 has timestamp 2026-02-03 11:05:02.985213-06:00
# Event 3368005-34 has 99 sub-events.
# Parsing NewEvent #35, data length 60232.
# data_str starts with ffffff11000649ee761d
# Found timestamp: 2026-02-03 11:06:32.955692-06:00, skipping ffffff11000649ee761d8b2c
# Event 3368104-35 has timestamp 2026-02-03 11:06:32.955692-06:00
# Event 3368104-35 has 99 sub-events.
# Parsing NewEvent #36, data length 60232.
# data_str starts with ffffff11000649ee7f0d
# Found timestamp: 2026-02-03 11:09:02.918060-06:00, skipping ffffff11000649ee7f0dc9ac
# Event 3368203-36 has timestamp 2026-02-03 11:09:02.918060-06:00
# Event 3368203-36 has 99 sub-events.
# Parsing NewEvent #37, data length 60232.
# data_str starts with ffffff11000649ee87fe
# Found timestamp: 2026-02-03 11:11:32.901539-06:00, skipping ffffff11000649ee87fe5aa3
# Event 3368302-37 has timestamp 2026-02-03 11:11:32.901539-06:00
# Event 3368302-37 has 99 sub-events.
# Parsing NewEvent #38, data length 60232.
# data_str starts with ffffff11000649ee8f25
# Found timestamp: 2026-02-03 11:13:32.914357-06:00, skipping ffffff11000649ee8f259ab5
# Event 3368401-38 has timestamp 2026-02-03 11:13:32.914357-06:00
# Event 3368401-38 has 99 sub-events.
# Parsing NewEvent #39, data length 60232.
# data_str starts with ffffff11000649ee90ef
# Found timestamp: 2026-02-03 11:14:02.917547-06:00, skipping ffffff11000649ee90ef6aab
# Event 3368500-39 has timestamp 2026-02-03 11:14:02.917547-06:00
# Event 3368500-39 has 99 sub-events.
# Parsing NewEvent #40, data length 60232.
# data_str starts with ffffff11000649ee92b9
# Found timestamp: 2026-02-03 11:14:32.917058-06:00, skipping ffffff11000649ee92b92c42
# Event 3368599-40 has timestamp 2026-02-03 11:14:32.917058-06:00
# Event 3368599-40 has 99 sub-events.
# Parsing NewEvent #41, data length 60232.
# data_str starts with ffffff11000649ee9816
# Found timestamp: 2026-02-03 11:16:02.919058-06:00, skipping ffffff11000649ee98167e92
# Event 3368698-41 has timestamp 2026-02-03 11:16:02.919058-06:00
# Event 3368698-41 has 99 sub-events.
# Parsing NewEvent #42, data length 60232.
# data_str starts with ffffff11000649ee99e0
# Found timestamp: 2026-02-03 11:16:32.928937-06:00, skipping ffffff11000649ee99e068a9
# Event 3368797-42 has timestamp 2026-02-03 11:16:32.928937-06:00
# Event 3368797-42 has 99 sub-events.
# Parsing NewEvent #43, data length 60232.
# data_str starts with ffffff11000649ee9d74
# Found timestamp: 2026-02-03 11:17:32.948668-06:00, skipping ffffff11000649ee9d743cbc
# Event 3368896-43 has timestamp 2026-02-03 11:17:32.948668-06:00
# Event 3368896-43 has 99 sub-events.
# Parsing NewEvent #44, data length 60296.
# data_str starts with ffffff11000649eea665
# Found timestamp: 2026-02-03 11:20:02.966532-06:00, skipping ffffff11000649eea6655404
# Event 3368995-44 has timestamp 2026-02-03 11:20:02.966532-06:00
# Event 3368995-44 has 99 sub-events.
# Parsing NewEvent #45, data length 60232.
# data_str starts with ffffff11000649eea841
# Found timestamp: 2026-02-03 11:20:34.167026-06:00, skipping ffffff11000649eea84168f2
# Event 3369094-45 has timestamp 2026-02-03 11:20:34.167026-06:00
# Event 3369094-45 has 99 sub-events.
# Parsing NewEvent #46, data length 60232.
# data_str starts with ffffff11000649eeabc2
# Found timestamp: 2026-02-03 11:21:32.968330-06:00, skipping ffffff11000649eeabc2a58a
# Event 3369193-46 has timestamp 2026-02-03 11:21:32.968330-06:00
# Event 3369193-46 has 99 sub-events.
# Parsing NewEvent #47, data length 60232.
# data_str starts with ffffff11000649eead8c
# Found timestamp: 2026-02-03 11:22:02.968623-06:00, skipping ffffff11000649eead8c6a2f
# Event 3369292-47 has timestamp 2026-02-03 11:22:02.968623-06:00
# Event 3369292-47 has 99 sub-events.
# Parsing NewEvent #48, data length 60232.
# data_str starts with ffffff11000649eeb30e
# Found timestamp: 2026-02-03 11:23:35.356011-06:00, skipping ffffff11000649eeb30e226b
# Event 3369391-48 has timestamp 2026-02-03 11:23:35.356011-06:00
# Event 3369391-48 has 99 sub-events.
# Parsing NewEvent #49, data length 60232.
# data_str starts with ffffff11000649eeb4b3
# Found timestamp: 2026-02-03 11:24:02.948792-06:00, skipping ffffff11000649eeb4b32ab8
# Event 3369490-49 has timestamp 2026-02-03 11:24:02.948792-06:00
# Event 3369490-49 has 99 sub-events.
# Parsing NewEvent #50, data length 60232.
# data_str starts with ffffff11000649eeb67c
# Found timestamp: 2026-02-03 11:24:32.940227-06:00, skipping ffffff11000649eeb67cccc3
# Event 3369589-50 has timestamp 2026-02-03 11:24:32.940227-06:00
# Event 3369589-50 has 99 sub-events.
# Parsing NewEvent #51, data length 60232.
# data_str starts with ffffff11000649eeb846
# Found timestamp: 2026-02-03 11:25:02.930876-06:00, skipping ffffff11000649eeb8466bbc
# Event 3369688-51 has timestamp 2026-02-03 11:25:02.930876-06:00
# Event 3369688-51 has 99 sub-events.
# Parsing NewEvent #52, data length 60232.
# data_str starts with ffffff11000649eebda3
# Found timestamp: 2026-02-03 11:26:32.913002-06:00, skipping ffffff11000649eebda3706a
# Event 3369787-52 has timestamp 2026-02-03 11:26:32.913002-06:00
# Event 3369787-52 has 99 sub-events.
# Parsing NewEvent #53, data length 60232.
# data_str starts with ffffff11000649eebf6d
# Found timestamp: 2026-02-03 11:27:02.904504-06:00, skipping ffffff11000649eebf6d12b8
# Event 3369886-53 has timestamp 2026-02-03 11:27:02.904504-06:00
# Event 3369886-53 has 99 sub-events.
# Parsing NewEvent #54, data length 60232.
# data_str starts with ffffff11000649eec136
# Found timestamp: 2026-02-03 11:27:32.895562-06:00, skipping ffffff11000649eec136b34a
# Event 3369985-54 has timestamp 2026-02-03 11:27:32.895562-06:00
# Event 3369985-54 has 99 sub-events.
# Parsing NewEvent #55, data length 60232.
# data_str starts with ffffff11000649eec300
# Found timestamp: 2026-02-03 11:28:02.882961-06:00, skipping ffffff11000649eec3004591
# Event 3370084-55 has timestamp 2026-02-03 11:28:02.882961-06:00
# Event 3370084-55 has 99 sub-events.
# Parsing NewEvent #56, data length 60232.
# data_str starts with ffffff11000649eeca26
# Found timestamp: 2026-02-03 11:30:02.841021-06:00, skipping ffffff11000649eeca26afbd
# Event 3370183-56 has timestamp 2026-02-03 11:30:02.841021-06:00
# Event 3370183-56 has 99 sub-events.
# Parsing NewEvent #57, data length 60232.
# data_str starts with ffffff11000649eecbf0
# Found timestamp: 2026-02-03 11:30:32.831530-06:00, skipping ffffff11000649eecbf04e2a
# Event 3370282-57 has timestamp 2026-02-03 11:30:32.831530-06:00
# Event 3370282-57 has 99 sub-events.
# Parsing NewEvent #58, data length 60232.
# data_str starts with ffffff11000649eed14d
# Found timestamp: 2026-02-03 11:32:02.810139-06:00, skipping ffffff11000649eed14d451b
# Event 3370381-58 has timestamp 2026-02-03 11:32:02.810139-06:00
# Event 3370381-58 has 99 sub-events.
# Parsing NewEvent #59, data length 60232.
# data_str starts with ffffff11000649eed4e0
# Found timestamp: 2026-02-03 11:33:02.800141-06:00, skipping ffffff11000649eed4e0a50d
# Event 3370480-59 has timestamp 2026-02-03 11:33:02.800141-06:00
# Event 3370480-59 has 99 sub-events.
# Parsing NewEvent #60, data length 60232.
# data_str starts with ffffff11000649eed6aa
# Found timestamp: 2026-02-03 11:33:32.789149-06:00, skipping ffffff11000649eed6aa3d9d
# Event 3370579-60 has timestamp 2026-02-03 11:33:32.789149-06:00
# Event 3370579-60 has 99 sub-events.
# Parsing NewEvent #61, data length 60232.
# data_str starts with ffffff11000649eee4f6
# Found timestamp: 2026-02-03 11:37:32.696884-06:00, skipping ffffff11000649eee4f6f134
# Event 3370678-61 has timestamp 2026-02-03 11:37:32.696884-06:00
# Event 3370678-61 has 99 sub-events.
# Parsing NewEvent #62, data length 60232.
# data_str starts with ffffff11000649eee6c0
# Found timestamp: 2026-02-03 11:38:02.686744-06:00, skipping ffffff11000649eee6c08d18
# Event 3370777-62 has timestamp 2026-02-03 11:38:02.686744-06:00
# Event 3370777-62 has 99 sub-events.
# Parsing NewEvent #63, data length 60232.
# data_str starts with ffffff11000649eee88a
# Found timestamp: 2026-02-03 11:38:32.675286-06:00, skipping ffffff11000649eee88a23d6
# Event 3370876-63 has timestamp 2026-02-03 11:38:32.675286-06:00
# Event 3370876-63 has 99 sub-events.
# Parsing NewEvent #64, data length 60232.
# data_str starts with ffffff11000649eeec1d
# Found timestamp: 2026-02-03 11:39:32.650728-06:00, skipping ffffff11000649eeec1d4ae8
# Event 3370975-64 has timestamp 2026-02-03 11:39:32.650728-06:00
# Event 3370975-64 has 99 sub-events.
# Parsing NewEvent #65, data length 60232.
# data_str starts with ffffff11000649eeede6
# Found timestamp: 2026-02-03 11:40:02.637959-06:00, skipping ffffff11000649eeede6dc87
# Event 3371074-65 has timestamp 2026-02-03 11:40:02.637959-06:00
# Event 3371074-65 has 99 sub-events.
# Parsing NewEvent #66, data length 60232.
# data_str starts with ffffff11000649eef343
# Found timestamp: 2026-02-03 11:41:32.614011-06:00, skipping ffffff11000649eef343c97b
# Event 3371173-66 has timestamp 2026-02-03 11:41:32.614011-06:00
# Event 3371173-66 has 99 sub-events.
# Parsing NewEvent #67, data length 60232.
# data_str starts with ffffff11000649eef8a0
# Found timestamp: 2026-02-03 11:43:02.580943-06:00, skipping ffffff11000649eef8a092cf
# Event 3371272-67 has timestamp 2026-02-03 11:43:02.580943-06:00
# Event 3371272-67 has 99 sub-events.
# Parsing NewEvent #68, data length 60232.
# data_str starts with ffffff11000649ef0524
# Found timestamp: 2026-02-03 11:46:32.530344-06:00, skipping ffffff11000649ef052425a8
# Event 3371371-68 has timestamp 2026-02-03 11:46:32.530344-06:00
# Event 3371371-68 has 99 sub-events.
# Parsing NewEvent #69, data length 60232.
# data_str starts with ffffff11000649ef0c4a
# Found timestamp: 2026-02-03 11:48:32.489037-06:00, skipping ffffff11000649ef0c4a924d
# Event 3371470-69 has timestamp 2026-02-03 11:48:32.489037-06:00
# Event 3371470-69 has 99 sub-events.
# Parsing NewEvent #70, data length 60232.
# data_str starts with ffffff11000649ef0e14
# Found timestamp: 2026-02-03 11:49:02.476035-06:00, skipping ffffff11000649ef0e142303
# Event 3371569-70 has timestamp 2026-02-03 11:49:02.476035-06:00
# Event 3371569-70 has 99 sub-events.
# Parsing NewEvent #71, data length 60232.
# data_str starts with ffffff11000649ef1371
# Found timestamp: 2026-02-03 11:50:32.459084-06:00, skipping ffffff11000649ef13712b4c
# Event 3371668-71 has timestamp 2026-02-03 11:50:32.459084-06:00
# Event 3371668-71 has 99 sub-events.
# Parsing NewEvent #72, data length 60232.
# data_str starts with ffffff11000649ef1a98
# Found timestamp: 2026-02-03 11:52:32.478523-06:00, skipping ffffff11000649ef1a98853b
# Event 3371767-72 has timestamp 2026-02-03 11:52:32.478523-06:00
# Event 3371767-72 has 99 sub-events.
# Parsing NewEvent #73, data length 60296.
# data_str starts with ffffff11000649ef2007
# Found timestamp: 2026-02-03 11:54:03.663788-06:00, skipping ffffff11000649ef2007e5ac
# Event 3371866-73 has timestamp 2026-02-03 11:54:03.663788-06:00
# Event 3371866-73 has 99 sub-events.
# Parsing NewEvent #74, data length 60296.
# data_str starts with ffffff11000649ef271c
# Found timestamp: 2026-02-03 11:56:02.431193-06:00, skipping ffffff11000649ef271c24d9
# Event 3371965-74 has timestamp 2026-02-03 11:56:02.431193-06:00
# Event 3371965-74 has 99 sub-events.
# Parsing NewEvent #75, data length 60232.
# data_str starts with ffffff11000649ef2c79
# Found timestamp: 2026-02-03 11:57:32.421178-06:00, skipping ffffff11000649ef2c79483a
# Event 3372064-75 has timestamp 2026-02-03 11:57:32.421178-06:00
# Event 3372064-75 has 99 sub-events.
# Parsing NewEvent #76, data length 60232.
# data_str starts with ffffff11000649ef31d6
# Found timestamp: 2026-02-03 11:59:02.389819-06:00, skipping ffffff11000649ef31d6183b
# Event 3372163-76 has timestamp 2026-02-03 11:59:02.389819-06:00
# Event 3372163-76 has 99 sub-events.
# Parsing NewEvent #77, data length 60232.
# data_str starts with ffffff11000649ef3e59
# Found timestamp: 2026-02-03 12:02:32.341586-06:00, skipping ffffff11000649ef3e59b452
# Event 3372262-77 has timestamp 2026-02-03 12:02:32.341586-06:00
# Event 3372262-77 has 99 sub-events.
# Parsing NewEvent #78, data length 60232.
# data_str starts with ffffff11000649ef43b6
# Found timestamp: 2026-02-03 12:04:02.337762-06:00, skipping ffffff11000649ef43b6efe2
# Event 3372361-78 has timestamp 2026-02-03 12:04:02.337762-06:00
# Event 3372361-78 has 99 sub-events.
# Parsing NewEvent #79, data length 60232.
# data_str starts with ffffff11000649ef4580
# Found timestamp: 2026-02-03 12:04:32.337939-06:00, skipping ffffff11000649ef4580b413
# Event 3372460-79 has timestamp 2026-02-03 12:04:32.337939-06:00
# Event 3372460-79 has 99 sub-events.
# Parsing NewEvent #80, data length 60232.
# data_str starts with ffffff11000649ef4926
# Found timestamp: 2026-02-03 12:05:33.540887-06:00, skipping ffffff11000649ef49269617
# Event 3372559-80 has timestamp 2026-02-03 12:05:33.540887-06:00
# Event 3372559-80 has 99 sub-events.
# Parsing NewEvent #81, data length 60232.
# data_str starts with ffffff11000649ef53ce
# Found timestamp: 2026-02-03 12:08:32.314776-06:00, skipping ffffff11000649ef53ce7598
# Event 3372658-81 has timestamp 2026-02-03 12:08:32.314776-06:00
# Event 3372658-81 has 99 sub-events.
# Parsing NewEvent #82, data length 60232.
# data_str starts with ffffff11000649ef592b
# Found timestamp: 2026-02-03 12:10:02.319164-06:00, skipping ffffff11000649ef592bd13c
# Event 3372757-82 has timestamp 2026-02-03 12:10:02.319164-06:00
# Event 3372757-82 has 99 sub-events.
# Parsing NewEvent #83, data length 60296.
# data_str starts with ffffff11000649ef6052
# Found timestamp: 2026-02-03 12:12:02.280456-06:00, skipping ffffff11000649ef60524808
# Event 3372856-83 has timestamp 2026-02-03 12:12:02.280456-06:00
# Event 3372856-83 has 99 sub-events.
# Parsing NewEvent #84, data length 60232.
# data_str starts with ffffff11000649ef63e5
# Found timestamp: 2026-02-03 12:13:02.256536-06:00, skipping ffffff11000649ef63e57198
# Event 3372955-84 has timestamp 2026-02-03 12:13:02.256536-06:00
# Event 3372955-84 has 99 sub-events.
# Parsing NewEvent #85, data length 60232.
# data_str starts with ffffff11000649ef65af
# Found timestamp: 2026-02-03 12:13:32.243416-06:00, skipping ffffff11000649ef65af01d8
# Event 3373054-85 has timestamp 2026-02-03 12:13:32.243416-06:00
# Event 3373054-85 has 99 sub-events.
# Parsing NewEvent #86, data length 60232.
# data_str starts with ffffff11000649ef6ce7
# Found timestamp: 2026-02-03 12:15:33.393428-06:00, skipping ffffff11000649ef6ce79c14
# Event 3373153-86 has timestamp 2026-02-03 12:15:33.393428-06:00
# Event 3373153-86 has 99 sub-events.
# Parsing NewEvent #87, data length 60232.
# data_str starts with ffffff11000649ef7244
# Found timestamp: 2026-02-03 12:17:03.358226-06:00, skipping ffffff11000649ef72445d12
# Event 3373252-87 has timestamp 2026-02-03 12:17:03.358226-06:00
# Event 3373252-87 has 99 sub-events.
# Parsing NewEvent #88, data length 60232.
# data_str starts with ffffff11000649ef73fb
# Found timestamp: 2026-02-03 12:17:32.142786-06:00, skipping ffffff11000649ef73fb94c2
# Event 3373351-88 has timestamp 2026-02-03 12:17:32.142786-06:00
# Event 3373351-88 has 99 sub-events.
# Parsing NewEvent #89, data length 60232.
# data_str starts with ffffff11000649ef7958
# Found timestamp: 2026-02-03 12:19:02.106651-06:00, skipping ffffff11000649ef7958521b
# Event 3373450-89 has timestamp 2026-02-03 12:19:02.106651-06:00
# Event 3373450-89 has 99 sub-events.
# Parsing NewEvent #90, data length 60232.
# data_str starts with ffffff11000649ef7b21
# Found timestamp: 2026-02-03 12:19:32.096220-06:00, skipping ffffff11000649ef7b21ecdc
# Event 3373549-90 has timestamp 2026-02-03 12:19:32.096220-06:00
# Event 3373549-90 has 99 sub-events.
# Parsing NewEvent #91, data length 60232.
# data_str starts with ffffff11000649ef7eb5
# Found timestamp: 2026-02-03 12:20:32.086565-06:00, skipping ffffff11000649ef7eb54e25
# Event 3373648-91 has timestamp 2026-02-03 12:20:32.086565-06:00
# Event 3373648-91 has 99 sub-events.
# Parsing NewEvent #92, data length 60232.
# data_str starts with ffffff11000649ef87a5
# Found timestamp: 2026-02-03 12:23:02.035186-06:00, skipping ffffff11000649ef87a556f2
# Event 3373747-92 has timestamp 2026-02-03 12:23:02.035186-06:00
# Event 3373747-92 has 99 sub-events.
# Parsing NewEvent #93, data length 60424.
# data_str starts with ffffff11000649ef8b38
# Found timestamp: 2026-02-03 12:24:02.011778-06:00, skipping ffffff11000649ef8b388282
# Event 3373846-93 has timestamp 2026-02-03 12:24:02.011778-06:00
# Event 3373846-93 has 99 sub-events.
# Parsing NewEvent #94, data length 60232.
# data_str starts with ffffff11000649ef925f
# Found timestamp: 2026-02-03 12:26:01.979839-06:00, skipping ffffff11000649ef925f13bf
# Event 3373945-94 has timestamp 2026-02-03 12:26:01.979839-06:00
# Event 3373945-94 has 99 sub-events.
# Parsing NewEvent #95, data length 60296.
# data_str starts with ffffff11000649ef9428
# Found timestamp: 2026-02-03 12:26:31.984404-06:00, skipping ffffff11000649ef9428e914
# Event 3374044-95 has timestamp 2026-02-03 12:26:31.984404-06:00
# Event 3374044-95 has 99 sub-events.
# Parsing NewEvent #96, data length 60232.
# data_str starts with ffffff11000649ef9986
# Found timestamp: 2026-02-03 12:28:01.991236-06:00, skipping ffffff11000649ef99864e44
# Event 3374143-96 has timestamp 2026-02-03 12:28:01.991236-06:00
# Event 3374143-96 has 99 sub-events.
# Parsing NewEvent #97, data length 60232.
# data_str starts with ffffff11000649ef9b4f
# Found timestamp: 2026-02-03 12:28:31.983505-06:00, skipping ffffff11000649ef9b4ff391
# Event 3374242-97 has timestamp 2026-02-03 12:28:31.983505-06:00
# Event 3374242-97 has 99 sub-events.
# Parsing NewEvent #98, data length 60232.
# data_str starts with ffffff11000649ef9d19
# Found timestamp: 2026-02-03 12:29:01.973432-06:00, skipping ffffff11000649ef9d198fb8
# Event 3374341-98 has timestamp 2026-02-03 12:29:01.973432-06:00
# Event 3374341-98 has 99 sub-events.
# Parsing NewEvent #99, data length 60232.
# data_str starts with ffffff11000649efa7d4
# Found timestamp: 2026-02-03 12:32:01.980956-06:00, skipping ffffff11000649efa7d4421c
# Event 3374440-99 has timestamp 2026-02-03 12:32:01.980956-06:00
# Event 3374440-99 has 99 sub-events.
# Parsing NewEvent #100, data length 60232.
# data_str starts with ffffff11000649efad31
# Found timestamp: 2026-02-03 12:33:31.976264-06:00, skipping ffffff11000649efad317a48
# Event 3374539-100 has timestamp 2026-02-03 12:33:31.976264-06:00
# Event 3374539-100 has 99 sub-events.
# Parsing NewEvent #101, data length 60232.
# data_str starts with ffffff11000649efb0c4
# Found timestamp: 2026-02-03 12:34:31.967967-06:00, skipping ffffff11000649efb0c4e0df
# Event 3374638-101 has timestamp 2026-02-03 12:34:31.967967-06:00
# Event 3374638-101 has 99 sub-events.
# Parsing NewEvent #102, data length 60232.
# data_str starts with ffffff11000649efb9b5
# Found timestamp: 2026-02-03 12:37:01.940127-06:00, skipping ffffff11000649efb9b5459f
# Event 3374737-102 has timestamp 2026-02-03 12:37:01.940127-06:00
# Event 3374737-102 has 99 sub-events.
# Parsing NewEvent #103, data length 60232.
# data_str starts with ffffff11000649efbf12
# Found timestamp: 2026-02-03 12:38:31.910953-06:00, skipping ffffff11000649efbf121e29
# Event 3374836-103 has timestamp 2026-02-03 12:38:31.910953-06:00
# Event 3374836-103 has 99 sub-events.
# Parsing NewEvent #104, data length 60232.
# data_str starts with ffffff11000649efc46e
# Found timestamp: 2026-02-03 12:40:01.874253-06:00, skipping ffffff11000649efc46ed94d
# Event 3374935-104 has timestamp 2026-02-03 12:40:01.874253-06:00
# Event 3374935-104 has 99 sub-events.
# Parsing NewEvent #105, data length 60232.
# data_str starts with ffffff11000649efc638
# Found timestamp: 2026-02-03 12:40:31.865108-06:00, skipping ffffff11000649efc6387914
# Event 3375034-105 has timestamp 2026-02-03 12:40:31.865108-06:00
# Event 3375034-105 has 99 sub-events.
# Parsing NewEvent #106, data length 60232.
# data_str starts with ffffff11000649efc9cb
# Found timestamp: 2026-02-03 12:41:31.836630-06:00, skipping ffffff11000649efc9cb90d6
# Event 3375133-106 has timestamp 2026-02-03 12:41:31.836630-06:00
# Event 3375133-106 has 99 sub-events.
# Parsing NewEvent #107, data length 60232.
# data_str starts with ffffff11000649efd818
# Found timestamp: 2026-02-03 12:45:31.752080-06:00, skipping ffffff11000649efd8186290
# Event 3375232-107 has timestamp 2026-02-03 12:45:31.752080-06:00
# Event 3375232-107 has 99 sub-events.
# Parsing NewEvent #108, data length 60232.
# data_str starts with ffffff11000649efdf51
# Found timestamp: 2026-02-03 12:47:32.926962-06:00, skipping ffffff11000649efdf515df2
# Event 3375331-108 has timestamp 2026-02-03 12:47:32.926962-06:00
# Event 3375331-108 has 99 sub-events.
# Parsing NewEvent #109, data length 64344.
# data_str starts with ffffff11000649f1953f
# Found timestamp: 2026-02-03 14:50:00.176250-06:00, skipping ffffff11000649f1953f7e7a
# Event 3375430-109 has timestamp 2026-02-03 14:50:00.176250-06:00
# Event 3375430-109 has 99 sub-events.
# Parsing NewEvent #110, data length 64248.
# data_str starts with ffffff11000649f19c66
# Found timestamp: 2026-02-03 14:52:00.171342-06:00, skipping ffffff11000649f19c66794e
# Event 3375529-110 has timestamp 2026-02-03 14:52:00.171342-06:00
# Event 3375529-110 has 99 sub-events.
# Parsing NewEvent #111, data length 64104.
# data_str starts with ffffff11000649f19e30
# Found timestamp: 2026-02-03 14:52:30.162370-06:00, skipping ffffff11000649f19e3019c2
# Event 3375628-111 has timestamp 2026-02-03 14:52:30.162370-06:00
# Event 3375628-111 has 99 sub-events.
# Parsing NewEvent #112, data length 64072.
# data_str starts with ffffff11000649f1a38d
# Found timestamp: 2026-02-03 14:54:00.147112-06:00, skipping ffffff11000649f1a38d28a8
# Event 3375727-112 has timestamp 2026-02-03 14:54:00.147112-06:00
# Event 3375727-112 has 99 sub-events.
# Parsing NewEvent #113, data length 63960.
# data_str starts with ffffff11000649f1a720
# Found timestamp: 2026-02-03 14:55:00.130371-06:00, skipping ffffff11000649f1a7206e43
# Event 3375826-113 has timestamp 2026-02-03 14:55:00.130371-06:00
# Event 3375826-113 has 99 sub-events.
# Parsing NewEvent #114, data length 64280.
# data_str starts with ffffff11000649f1a8ea
# Found timestamp: 2026-02-03 14:55:30.121526-06:00, skipping ffffff11000649f1a8ea0f36
# Event 3375925-114 has timestamp 2026-02-03 14:55:30.121526-06:00
# Event 3375925-114 has 99 sub-events.
# Parsing NewEvent #115, data length 63848.
# data_str starts with ffffff11000649f1aab3
# Found timestamp: 2026-02-03 14:56:00.109069-06:00, skipping ffffff11000649f1aab3a20d
# Event 3376024-115 has timestamp 2026-02-03 14:56:00.109069-06:00
# Event 3376024-115 has 99 sub-events.
# Parsing NewEvent #116, data length 64152.
# data_str starts with ffffff11000649f1ae46
# Found timestamp: 2026-02-03 14:57:00.081132-06:00, skipping ffffff11000649f1ae46bbec
# Event 3376123-116 has timestamp 2026-02-03 14:57:00.081132-06:00
# Event 3376123-116 has 99 sub-events.
# Parsing NewEvent #117, data length 64088.
# data_str starts with ffffff11000649f1b010
# Found timestamp: 2026-02-03 14:57:30.066495-06:00, skipping ffffff11000649f1b010463f
# Event 3376222-117 has timestamp 2026-02-03 14:57:30.066495-06:00
# Event 3376222-117 has 99 sub-events.
# Parsing NewEvent #118, data length 64264.
# data_str starts with ffffff11000649f1b56c
# Found timestamp: 2026-02-03 14:59:00.025208-06:00, skipping ffffff11000649f1b56cef78
# Event 3376321-118 has timestamp 2026-02-03 14:59:00.025208-06:00
# Event 3376321-118 has 99 sub-events.
# Parsing NewEvent #119, data length 64344.
# data_str starts with ffffff11000649f1c1f0
# Found timestamp: 2026-02-03 15:02:29.942295-06:00, skipping ffffff11000649f1c1f00417
# Event 3376420-119 has timestamp 2026-02-03 15:02:29.942295-06:00
# Event 3376420-119 has 99 sub-events.
# Parsing NewEvent #120, data length 64040.
# data_str starts with ffffff11000649f1cae0
# Found timestamp: 2026-02-03 15:04:59.906953-06:00, skipping ffffff11000649f1cae04b89
# Event 3376519-120 has timestamp 2026-02-03 15:04:59.906953-06:00
# Event 3376519-120 has 99 sub-events.
# Parsing NewEvent #121, data length 64136.
# data_str starts with ffffff11000649f1cca9
# Found timestamp: 2026-02-03 15:05:29.902209-06:00, skipping ffffff11000649f1cca9fc81
# Event 3376618-121 has timestamp 2026-02-03 15:05:29.902209-06:00
# Event 3376618-121 has 99 sub-events.
# Parsing NewEvent #122, data length 64424.
# data_str starts with ffffff11000649f1d207
# Found timestamp: 2026-02-03 15:06:59.900472-06:00, skipping ffffff11000649f1d2074038
# Event 3376717-122 has timestamp 2026-02-03 15:06:59.900472-06:00
# Event 3376717-122 has 99 sub-events.
# Parsing NewEvent #123, data length 63848.
# data_str starts with ffffff11000649f1d3d1
# Found timestamp: 2026-02-03 15:07:29.901123-06:00, skipping ffffff11000649f1d3d10643
# Event 3376816-123 has timestamp 2026-02-03 15:07:29.901123-06:00
# Event 3376816-123 has 99 sub-events.
# Parsing NewEvent #124, data length 63928.
# data_str starts with ffffff11000649f1d59a
# Found timestamp: 2026-02-03 15:07:59.896159-06:00, skipping ffffff11000649f1d59ab65f
# Event 3376915-124 has timestamp 2026-02-03 15:07:59.896159-06:00
# Event 3376915-124 has 99 sub-events.
# Parsing NewEvent #125, data length 64184.
# data_str starts with ffffff11000649f1d764
# Found timestamp: 2026-02-03 15:08:29.891591-06:00, skipping ffffff11000649f1d7646807
# Event 3377014-125 has timestamp 2026-02-03 15:08:29.891591-06:00
# Event 3377014-125 has 99 sub-events.
# Parsing NewEvent #126, data length 64104.
# data_str starts with ffffff11000649f1daf7
# Found timestamp: 2026-02-03 15:09:29.880591-06:00, skipping ffffff11000649f1daf7c40f
# Event 3377113-126 has timestamp 2026-02-03 15:09:29.880591-06:00
# Event 3377113-126 has 99 sub-events.
# Parsing NewEvent #127, data length 64104.
# data_str starts with ffffff11000649f1e054
# Found timestamp: 2026-02-03 15:10:59.850782-06:00, skipping ffffff11000649f1e0549a1e
# Event 3377212-127 has timestamp 2026-02-03 15:10:59.850782-06:00
# Event 3377212-127 has 99 sub-events.
# Parsing NewEvent #128, data length 64072.
# data_str starts with ffffff11000649f1e21e
# Found timestamp: 2026-02-03 15:11:29.843391-06:00, skipping ffffff11000649f1e21e40bf
# Event 3377311-128 has timestamp 2026-02-03 15:11:29.843391-06:00
# Event 3377311-128 has 99 sub-events.
# Parsing NewEvent #129, data length 64216.
# data_str starts with ffffff11000649f1e3e7
# Found timestamp: 2026-02-03 15:11:59.835690-06:00, skipping ffffff11000649f1e3e7e62a
# Event 3377410-129 has timestamp 2026-02-03 15:11:59.835690-06:00
# Event 3377410-129 has 99 sub-events.
# Parsing NewEvent #130, data length 64216.
# data_str starts with ffffff11000649f1e5b1
# Found timestamp: 2026-02-03 15:12:29.827725-06:00, skipping ffffff11000649f1e5b18a8d
# Event 3377509-130 has timestamp 2026-02-03 15:12:29.827725-06:00
# Event 3377509-130 has 99 sub-events.
# Parsing NewEvent #131, data length 64152.
# data_str starts with ffffff11000649f1e77b
# Found timestamp: 2026-02-03 15:12:59.818467-06:00, skipping ffffff11000649f1e77b29e3
# Event 3377608-131 has timestamp 2026-02-03 15:12:59.818467-06:00
# Event 3377608-131 has 99 sub-events.
# Parsing NewEvent #132, data length 63944.
# data_str starts with ffffff11000649f1e944
# Found timestamp: 2026-02-03 15:13:29.817897-06:00, skipping ffffff11000649f1e944eb29
# Event 3377707-132 has timestamp 2026-02-03 15:13:29.817897-06:00
# Event 3377707-132 has 99 sub-events.
# Parsing NewEvent #133, data length 60232.
# data_str starts with ffffff11000649f1ecea
# Found timestamp: 2026-02-03 15:14:31.028871-06:00, skipping ffffff11000649f1eceaec87
# Event 3377806-133 has timestamp 2026-02-03 15:14:31.028871-06:00
# Event 3377806-133 has 99 sub-events.
# Parsing NewEvent #134, data length 64360.
# data_str starts with ffffff11000649f1f236
# Found timestamp: 2026-02-03 15:15:59.844204-06:00, skipping ffffff11000649f1f236236c
# Event 3377905-134 has timestamp 2026-02-03 15:15:59.844204-06:00
# Event 3377905-134 has 99 sub-events.
# Parsing NewEvent #135, data length 64264.
# data_str starts with ffffff11000649f1f3ff
# Found timestamp: 2026-02-03 15:16:29.845194-06:00, skipping ffffff11000649f1f3ffeaca
# Event 3378004-135 has timestamp 2026-02-03 15:16:29.845194-06:00
# Event 3378004-135 has 99 sub-events.
# Parsing NewEvent #136, data length 64024.
# data_str starts with ffffff11000649f1f5c9
# Found timestamp: 2026-02-03 15:16:59.849229-06:00, skipping ffffff11000649f1f5c9be0d
# Event 3378103-136 has timestamp 2026-02-03 15:16:59.849229-06:00
# Event 3378103-136 has 99 sub-events.
# Parsing NewEvent #137, data length 64536.
# data_str starts with ffffff11000649f1f793
# Found timestamp: 2026-02-03 15:17:29.853923-06:00, skipping ffffff11000649f1f79393e3
# Event 3378202-137 has timestamp 2026-02-03 15:17:29.853923-06:00
# Event 3378202-137 has 99 sub-events.
# Parsing NewEvent #138, data length 64456.
# data_str starts with ffffff11000649f1f95d
# Found timestamp: 2026-02-03 15:17:59.848795-06:00, skipping ffffff11000649f1f95d435b
# Event 3378301-138 has timestamp 2026-02-03 15:17:59.848795-06:00
# Event 3378301-138 has 99 sub-events.
# Parsing NewEvent #139, data length 64008.
# data_str starts with ffffff11000649f2024d
# Found timestamp: 2026-02-03 15:20:29.827852-06:00, skipping ffffff11000649f2024dc30c
# Event 3378400-139 has timestamp 2026-02-03 15:20:29.827852-06:00
# Event 3378400-139 has 99 sub-events.
# Parsing NewEvent #140, data length 64584.
# data_str starts with ffffff11000649f205e1
# Found timestamp: 2026-02-03 15:21:29.831530-06:00, skipping ffffff11000649f205e1586a
# Event 3378499-140 has timestamp 2026-02-03 15:21:29.831530-06:00
# Event 3378499-140 has 99 sub-events.
# Parsing NewEvent #141, data length 64072.
# data_str starts with ffffff11000649f207ab
# Found timestamp: 2026-02-03 15:21:59.832954-06:00, skipping ffffff11000649f207ab217a
# Event 3378598-141 has timestamp 2026-02-03 15:21:59.832954-06:00
# Event 3378598-141 has 99 sub-events.
# Parsing NewEvent #142, data length 64520.
# data_str starts with ffffff11000649f20b3e
# Found timestamp: 2026-02-03 15:22:59.840519-06:00, skipping ffffff11000649f20b3ec607
# Event 3378697-142 has timestamp 2026-02-03 15:22:59.840519-06:00
# Event 3378697-142 has 99 sub-events.
# Parsing NewEvent #143, data length 60232.
# data_str starts with ffffff11000649f2160b
# Found timestamp: 2026-02-03 15:26:01.058835-06:00, skipping ffffff11000649f2160bf213
# Event 3378796-143 has timestamp 2026-02-03 15:26:01.058835-06:00
# Event 3378796-143 has 99 sub-events.
# Parsing NewEvent #144, data length 64424.
# data_str starts with ffffff11000649f217c3
# Found timestamp: 2026-02-03 15:26:29.865906-06:00, skipping ffffff11000649f217c381b2
# Event 3378895-144 has timestamp 2026-02-03 15:26:29.865906-06:00
# Event 3378895-144 has 99 sub-events.
# Parsing NewEvent #145, data length 64296.
# data_str starts with ffffff11000649f21eea
# Found timestamp: 2026-02-03 15:28:29.872640-06:00, skipping ffffff11000649f21eeaaa00
# Event 3378994-145 has timestamp 2026-02-03 15:28:29.872640-06:00
# Event 3378994-145 has 99 sub-events.
# Parsing NewEvent #146, data length 64200.
# data_str starts with ffffff11000649f22611
# Found timestamp: 2026-02-03 15:30:29.888909-06:00, skipping ffffff11000649f22611f78d
# Event 3379093-146 has timestamp 2026-02-03 15:30:29.888909-06:00
# Event 3379093-146 has 99 sub-events.
# Parsing NewEvent #147, data length 64488.
# data_str starts with ffffff11000649f22f03
# Found timestamp: 2026-02-03 15:32:59.916786-06:00, skipping ffffff11000649f22f0335f2
# Event 3379192-147 has timestamp 2026-02-03 15:32:59.916786-06:00
# Event 3379192-147 has 99 sub-events.
# Parsing NewEvent #148, data length 64152.
# data_str starts with ffffff11000649f23296
# Found timestamp: 2026-02-03 15:33:59.912974-06:00, skipping ffffff11000649f23296ae0e
# Event 3379291-148 has timestamp 2026-02-03 15:33:59.912974-06:00
# Event 3379291-148 has 99 sub-events.
# Parsing NewEvent #149, data length 64280.
# data_str starts with ffffff11000649f23b88
# Found timestamp: 2026-02-03 15:36:29.954001-06:00, skipping ffffff11000649f23b881fd1
# Event 3379390-149 has timestamp 2026-02-03 15:36:29.954001-06:00
# Event 3379390-149 has 99 sub-events.
# Parsing NewEvent #150, data length 63960.
# data_str starts with ffffff11000649f24479
# Found timestamp: 2026-02-03 15:38:59.978987-06:00, skipping ffffff11000649f2447952eb
# Event 3379489-150 has timestamp 2026-02-03 15:38:59.978987-06:00
# Event 3379489-150 has 99 sub-events.
# Parsing NewEvent #151, data length 60232.
# data_str starts with ffffff11000649f24655
# Found timestamp: 2026-02-03 15:39:31.195335-06:00, skipping ffffff11000649f24655a5c7
# Event 3379588-151 has timestamp 2026-02-03 15:39:31.195335-06:00
# Event 3379588-151 has 99 sub-events.
# Parsing NewEvent #152, data length 64264.
# data_str starts with ffffff11000649f2480d
# Found timestamp: 2026-02-03 15:40:00.006964-06:00, skipping ffffff11000649f2480d4734
# Event 3379687-152 has timestamp 2026-02-03 15:40:00.006964-06:00
# Event 3379687-152 has 99 sub-events.
# Parsing NewEvent #153, data length 64392.
# data_str starts with ffffff11000649f24d6a
# Found timestamp: 2026-02-03 15:41:30.001775-06:00, skipping ffffff11000649f24d6a7d6f
# Event 3379786-153 has timestamp 2026-02-03 15:41:30.001775-06:00
# Event 3379786-153 has 99 sub-events.
# Parsing NewEvent #154, data length 64120.
# data_str starts with ffffff11000649f250fd
# Found timestamp: 2026-02-03 15:42:29.977544-06:00, skipping ffffff11000649f250fda5c8
# Event 3379885-154 has timestamp 2026-02-03 15:42:29.977544-06:00
# Event 3379885-154 has 99 sub-events.
# Parsing NewEvent #155, data length 64312.
# data_str starts with ffffff11000649f252c7
# Found timestamp: 2026-02-03 15:42:59.965921-06:00, skipping ffffff11000649f252c73be1
# Event 3379984-155 has timestamp 2026-02-03 15:42:59.965921-06:00
# Event 3379984-155 has 99 sub-events.
# Parsing NewEvent #156, data length 63976.
# data_str starts with ffffff11000649f25d81
# Found timestamp: 2026-02-03 15:45:59.946884-06:00, skipping ffffff11000649f25d818684
# Event 3380083-156 has timestamp 2026-02-03 15:45:59.946884-06:00
# Event 3380083-156 has 99 sub-events.
# Parsing NewEvent #157, data length 63816.
# data_str starts with ffffff11000649f26115
# Found timestamp: 2026-02-03 15:46:59.970659-06:00, skipping ffffff11000649f261156a63
# Event 3380182-157 has timestamp 2026-02-03 15:46:59.970659-06:00
# Event 3380182-157 has 99 sub-events.
# Parsing NewEvent #158, data length 64632.
# data_str starts with ffffff11000649f26a06
# Found timestamp: 2026-02-03 15:49:29.991436-06:00, skipping ffffff11000649f26a068d0c
# Event 3380281-158 has timestamp 2026-02-03 15:49:29.991436-06:00
# Event 3380281-158 has 99 sub-events.
# Parsing NewEvent #159, data length 64632.
# data_str starts with ffffff11000649f26f63
# Found timestamp: 2026-02-03 15:50:59.991188-06:00, skipping ffffff11000649f26f63d694
# Event 3380380-159 has timestamp 2026-02-03 15:50:59.991188-06:00
# Event 3380380-159 has 99 sub-events.
# Parsing NewEvent #160, data length 64248.
# data_str starts with ffffff11000649f2886b
# Found timestamp: 2026-02-03 15:57:59.941727-06:00, skipping ffffff11000649f2886bc65f
# Event 3380479-160 has timestamp 2026-02-03 15:57:59.941727-06:00
# Event 3380479-160 has 99 sub-events.
# Parsing NewEvent #161, data length 64520.
# data_str starts with ffffff11000649f28f93
# Found timestamp: 2026-02-03 15:59:59.971638-06:00, skipping ffffff11000649f28f934936
# Event 3380578-161 has timestamp 2026-02-03 15:59:59.971638-06:00
# Event 3380578-161 has 99 sub-events.
# Parsing NewEvent #162, data length 64328.
# data_str starts with ffffff11000649f294f0
# Found timestamp: 2026-02-03 16:01:29.943055-06:00, skipping ffffff11000649f294f0240f
# Event 3380677-162 has timestamp 2026-02-03 16:01:29.943055-06:00
# Event 3380677-162 has 99 sub-events.
# Parsing NewEvent #163, data length 63992.
# data_str starts with ffffff11000649f2a174
# Found timestamp: 2026-02-03 16:04:59.911985-06:00, skipping ffffff11000649f2a1740331
# Event 3380776-163 has timestamp 2026-02-03 16:04:59.911985-06:00
# Event 3380776-163 has 99 sub-events.
# Parsing NewEvent #164, data length 64360.
# data_str starts with ffffff11000649f2adf8
# Found timestamp: 2026-02-03 16:08:29.937460-06:00, skipping ffffff11000649f2adf8bf34
# Event 3380875-164 has timestamp 2026-02-03 16:08:29.937460-06:00
# Event 3380875-164 has 99 sub-events.
# Parsing NewEvent #165, data length 64360.
# data_str starts with ffffff11000649f2b18c
# Found timestamp: 2026-02-03 16:09:29.955397-06:00, skipping ffffff11000649f2b18c8c45
# Event 3380974-165 has timestamp 2026-02-03 16:09:29.955397-06:00
# Event 3380974-165 has 99 sub-events.
# Parsing NewEvent #166, data length 64536.
# data_str starts with ffffff11000649f2b6ea
# Found timestamp: 2026-02-03 16:10:59.988144-06:00, skipping ffffff11000649f2b6ea56b0
# Event 3381073-166 has timestamp 2026-02-03 16:10:59.988144-06:00
# Event 3381073-166 has 99 sub-events.
# Parsing NewEvent #167, data length 64072.
# data_str starts with ffffff11000649f2ba7e
# Found timestamp: 2026-02-03 16:12:00.009292-06:00, skipping ffffff11000649f2ba7e304c
# Event 3381172-167 has timestamp 2026-02-03 16:12:00.009292-06:00
# Event 3381172-167 has 99 sub-events.
# Parsing NewEvent #168, data length 64472.
# data_str starts with ffffff11000649f2be11
# Found timestamp: 2026-02-03 16:13:00.022734-06:00, skipping ffffff11000649f2be11ebce
# Event 3381271-168 has timestamp 2026-02-03 16:13:00.022734-06:00
# Event 3381271-168 has 99 sub-events.
# Parsing NewEvent #169, data length 64024.
# data_str starts with ffffff11000649f2c36f
# Found timestamp: 2026-02-03 16:14:30.055774-06:00, skipping ffffff11000649f2c36fb75e
# Event 3381370-169 has timestamp 2026-02-03 16:14:30.055774-06:00
# Event 3381370-169 has 99 sub-events.
# Parsing NewEvent #170, data length 60232.
# data_str starts with ffffff11000649f2cc73
# Found timestamp: 2026-02-03 16:17:01.295451-06:00, skipping ffffff11000649f2cc73735b
# Event 3381469-170 has timestamp 2026-02-03 16:17:01.295451-06:00
# Event 3381469-170 has 99 sub-events.
# Parsing NewEvent #171, data length 64008.
# data_str starts with ffffff11000649f2ce2b
# Found timestamp: 2026-02-03 16:17:30.104696-06:00, skipping ffffff11000649f2ce2b0b78
# Event 3381568-171 has timestamp 2026-02-03 16:17:30.104696-06:00
# Event 3381568-171 has 99 sub-events.
# Parsing NewEvent #172, data length 64216.
# data_str starts with ffffff11000649f2cff4
# Found timestamp: 2026-02-03 16:18:00.112799-06:00, skipping ffffff11000649f2cff4ee9f
# Event 3381667-172 has timestamp 2026-02-03 16:18:00.112799-06:00
# Event 3381667-172 has 99 sub-events.
# Parsing NewEvent #173, data length 60232.
# data_str starts with ffffff11000649f2d1e3
# Found timestamp: 2026-02-03 16:18:32.522022-06:00, skipping ffffff11000649f2d1e37526
# Event 3381766-173 has timestamp 2026-02-03 16:18:32.522022-06:00
# Event 3381766-173 has 99 sub-events.
# Parsing NewEvent #174, data length 64536.
# data_str starts with ffffff11000649f2d388
# Found timestamp: 2026-02-03 16:19:00.139374-06:00, skipping ffffff11000649f2d388dd6e
# Event 3381865-174 has timestamp 2026-02-03 16:19:00.139374-06:00
# Event 3381865-174 has 99 sub-events.
# Parsing NewEvent #175, data length 64344.
# data_str starts with ffffff11000649f2d8e7
# Found timestamp: 2026-02-03 16:20:30.200172-06:00, skipping ffffff11000649f2d8e7156c
# Event 3381964-175 has timestamp 2026-02-03 16:20:30.200172-06:00
# Event 3381964-175 has 99 sub-events.
# Parsing NewEvent #176, data length 64312.
# data_str starts with ffffff11000649f2dab1
# Found timestamp: 2026-02-03 16:21:00.220181-06:00, skipping ffffff11000649f2dab12715
# Event 3382063-176 has timestamp 2026-02-03 16:21:00.220181-06:00
# Event 3382063-176 has 99 sub-events.
# Parsing NewEvent #177, data length 60232.
# data_str starts with ffffff11000649f2de45
# Found timestamp: 2026-02-03 16:22:00.246600-06:00, skipping ffffff11000649f2de451548
# Event 3382162-177 has timestamp 2026-02-03 16:22:00.246600-06:00
# Event 3382162-177 has 99 sub-events.
# Parsing NewEvent #178, data length 60232.
# data_str starts with ffffff11000649f2e8ff
# Found timestamp: 2026-02-03 16:25:00.234869-06:00, skipping ffffff11000649f2e8ff7c75
# Event 3382261-178 has timestamp 2026-02-03 16:25:00.234869-06:00
# Event 3382261-178 has 99 sub-events.
# Parsing NewEvent #179, data length 60232.
# data_str starts with ffffff11000649f2eac9
# Found timestamp: 2026-02-03 16:25:30.245666-06:00, skipping ffffff11000649f2eac96a22
# Event 3382360-179 has timestamp 2026-02-03 16:25:30.245666-06:00
# Event 3382360-179 has 99 sub-events.
# Parsing NewEvent #180, data length 60232.
# data_str starts with ffffff11000649f2ee5c
# Found timestamp: 2026-02-03 16:26:30.239929-06:00, skipping ffffff11000649f2ee5cdab9
# Event 3382459-180 has timestamp 2026-02-03 16:26:30.239929-06:00
# Event 3382459-180 has 99 sub-events.
# Parsing NewEvent #181, data length 64056.
# data_str starts with ffffff11000649f2f026
# Found timestamp: 2026-02-03 16:27:00.225990-06:00, skipping ffffff11000649f2f02667c6
# Event 3382558-181 has timestamp 2026-02-03 16:27:00.225990-06:00
# Event 3382558-181 has 99 sub-events.
# Parsing NewEvent #182, data length 63944.
# data_str starts with ffffff11000649f2f916
# Found timestamp: 2026-02-03 16:29:30.202962-06:00, skipping ffffff11000649f2f916df52
# Event 3382657-182 has timestamp 2026-02-03 16:29:30.202962-06:00
# Event 3382657-182 has 99 sub-events.
# Parsing NewEvent #183, data length 54368.
# data_str starts with ffffff11000649f2fcaa
# Found timestamp: 2026-02-03 16:30:30.195810-06:00, skipping ffffff11000649f2fcaa4a62
# Event 3382756-183 has timestamp 2026-02-03 16:30:30.195810-06:00
# Event 3382756-183 has 83 sub-events.

# %%
from socketudp.extinction_plots import plot_raw_data

# plot_raw_data(hc, event_range=(0,5), n_subevents=99, figsize=(20, 14),
#               plotting_units='raw',
#               # t_range=(1130,1330),
#               # y_range=(-0.03, 0.005),
#               )

# %%
from socketudp.hex_check_classes import PeakHeight
from socketudp.extinction_plots import peak_width_classification

# Calculate average width in time of peaks from peak area packets

peak_areas: list[PeakArea] = []
peak_heights: list[PeakHeight] = []
for event in hc.event_buffer:
    event: NewEvent
    for subevent in event.sub_events:
        # print(subevent.peak_area_list)
        peak_areas += subevent.peak_area_list[1]
        peak_heights += subevent.peak_height_list[1]

# print(peak_areas[0], len(peak_areas))
# print(peak_heights[0], len(peak_heights))

# peak_widths = [p.peak_width for p in peak_areas]

peak_width_classification(peak_areas)
peak_width_classification(peak_heights, type="height")  # this plots peak heights, but plots will all be labeled as "width/area"
# Out:
# Peak widths (n=6): mean=10 samples, median=10, std=2.19089
# min=8, max=12
# Peak widths (n=6): mean=8.5 samples, median=7.5, std=4.13521
# min=5, max=16

# %%
# last_event = hc.event_buffer[-1]
# print(f"# Events / Subevents: {last_event.internal_event_number} / {last_event.sub_event_number}")

# all times in this file are in nanoseconds unless otherwise specified
signal_period = 1 / 589.9801  # ns, the nominal period of the signal, 1694.97242 ns
sample_rate = 4  # ns, the sampling rate of the signal (4 ns per sample)

use = "real_data"  # "real_data" or "simulated_data"
# FOR SIMULATED DATA
length_ms = 30
length_ns: int = int(length_ms * 1e6)  # ns, total time for the delta train
# arrival_jitter derived based on requirement for ~99.99893% of protons within ±125 ns
arrival_jitter_ns = 27.14
particle_num_mean = 3
particle_num_width = 2
noise_num_mean = 0.1
noise_num_width = 0.15
phase_offset_deg = 0
gradual_phase_shift_speed_ns = 5  # ns, the speed of the gradual phase shift in the signal

# OTHER SETTINGS
desired_f_resolution = 0.1  # kHz, desired frequency resolution for the FFT
zero_padding_ratio = 5  # set to None to calc. zero padding based on desired_f_resolution
common_title_text = ""  # leave unfilled, is set at beginning of main()

# 4 ns sample rate
# total_time = 1695 * 501 ns = 849,195 ns = 0.849195 ms
# fs = 1 / (4e-9) = 250 MHz
# fn = fs / 2 = 125 MHz
print(f"Sampling rate (fs): {1 / sample_rate * 1e6} MHz ({sample_rate} ns)")
print(f"Nyquist frequency (fn): {1 / (2 * sample_rate) * 1e6} MHz ({2 * sample_rate} ns)")

if use == 'real_data':
    common_title_text = f"{hc.file_name}"
else:
    common_title_text = f"Simulated Delta Train (length: {length_ms} ms, "
    common_title_text += f"signal period: {signal_period} ns, sample rate: {sample_rate} ns)"
# Out:
# Sampling rate (fs): 250000.0 MHz (4 ns)
# Nyquist frequency (fn): 125000.0 MHz (8 ns)

# %%
def get_delta_train(channel, fft_time_range_ns: tuple[float, float] = (None, None)):
    global common_title_text
    if use == "real_data":
        delta_train, fft_time_range_ns = get_delta_trains_from_hex(hc, channel, fft_time_range_ns)
        if delta_train.size == 0:
            return delta_train, fft_time_range_ns
        print(delta_train[0], delta_train[-1], )
        if "Time Range" not in common_title_text:
            common_title_text += (f"\nTime Range: {delta_train[0] * 1e-6:.2f} "
                                  f"to {delta_train[-1] * 1e-6:.2f} ms")
    elif use == "simulated_data":
        delta_train = simulate_delta_train(signal_period, phase_offset_deg, arrival_jitter_ns,
                                           particle_num_mean, particle_num_width, noise_num_mean,
                                           noise_num_width,
                                           length_ns, sample_rate)
        fft_time_range_ns = (delta_train[0], delta_train[-1])  # default to full range
    else:
        raise ValueError("Invalid use case. Use 'real_data' or 'simulated_data'.")

    return delta_train, fft_time_range_ns

# %%
from extinction_plots import plot_2d_histogram_time_vs_event_number

def get_delta_train_per_event(channel: int,
                              fft_time_range_ns: tuple[float, float] = (None, None),
                              period=None):
    """
    Get delta train for a specific channel and event.
    :param channel: Channel number (1, 2, or 3).
    :param fft_time_range_ns: Time range for FFT in nanoseconds.
    :return: Delta train and time range for FFT.
    """
    r = get_delta_trains_per_event_from_hex(hc, channel, fft_time_range_ns, units='ns', period=period)
    return r

# t_range_begin_ns = 29.5e6
# t_range = (t_range_begin_ns, t_range_begin_ns + 1695*15)
t_range = (0, 100e6)
print(f"File name: {hc.file_name}")

for i in range(4):
    delta_trains_per_event, fft_time_range_ns_2 = get_delta_train_per_event(channel=i+1,
                                                                            fft_time_range_ns=t_range)
    print(f"[CH{i+1}] Received {len(delta_trains_per_event)} delta trains")


    plot_2d_histogram_time_vs_event_number(
        delta_trains_per_event,
        bin_width = 0.03,
        units='ms',
        t_range=(0, 50e6)
    )

    # if i == 0:
    #     plot_2d_histogram_time_vs_event_number(
    #     delta_trains_per_event,
    #     bin_width = 0.03,
    #     units='ms',
    #     t_range=(12.5e6, 17.5e6)
    # )
# Out:
# File name: data_20260203_101900.dat
# [CH1] Event 5: 1 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH1] Event 12: 1 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH1] Event 32: 1 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH1] Event 33: 1 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH1] Event 44: 1 peaks heights(1 from t = 0 to 100000000.0 ns).
# [CH1] Event 73: 1 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH1] Event 74: 1 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH1] Event 83: 1 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH1] Event 93: 1 peaks heights(1 from t = 0 to 100000000.0 ns).
# [CH1] Event 123: 1 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH1] Event 128: 1 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH1] Event 145: 1 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH1] Received 12 delta trains
# No data in specified t_range; nothing to plot.
# [CH2] Event 93: 1 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH2] Event 159: 1 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH2] Event 172: 1 peaks heights(1 from t = 0 to 100000000.0 ns).
# [CH2] Received 3 delta trains
# [CH3] Event 18: 1 peaks heights(1 from t = 0 to 100000000.0 ns).
# [CH3] Event 21: 1 peaks heights(1 from t = 0 to 100000000.0 ns).
# [CH3] Event 34: 1 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH3] Event 93: 1 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH3] Event 95: 1 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH3] Event 158: 1 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH3] Received 6 delta trains
# [CH4] Event 109: 248 peaks heights(248 from t = 0 to 100000000.0 ns).
# [CH4] Event 110: 236 peaks heights(236 from t = 0 to 100000000.0 ns).
# [CH4] Event 111: 230 peaks heights(230 from t = 0 to 100000000.0 ns).
# [CH4] Event 112: 231 peaks heights(231 from t = 0 to 100000000.0 ns).
# [CH4] Event 113: 215 peaks heights(215 from t = 0 to 100000000.0 ns).
# [CH4] Event 114: 238 peaks heights(238 from t = 0 to 100000000.0 ns).
# [CH4] Event 115: 217 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 116: 236 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 117: 232 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 118: 246 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 119: 245 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 120: 229 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 121: 232 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 122: 247 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 123: 216 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 124: 219 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 125: 232 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 126: 227 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 127: 224 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 128: 224 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 129: 243 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 130: 243 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 131: 236 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 132: 223 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 134: 240 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 135: 240 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 136: 225 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 137: 254 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 138: 246 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 139: 227 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 140: 260 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 141: 231 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 142: 256 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 144: 244 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 145: 238 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 146: 233 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 147: 251 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 148: 230 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 149: 238 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 150: 224 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 152: 243 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 153: 245 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 154: 234 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 155: 240 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 156: 225 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 157: 215 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 158: 253 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 159: 259 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 160: 236 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 161: 256 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 162: 247 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 163: 223 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 164: 246 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 165: 246 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 166: 248 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 167: 228 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 168: 253 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 169: 225 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 171: 221 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 172: 236 peaks heights(0 from t = 0 to 100000000.0 ns).
# [CH4] Event 174: 254 peaks heights(254 from t = 0 to 100000000.0 ns).
# [CH4] Event 175: 239 peaks heights(239 from t = 0 to 100000000.0 ns).
# [CH4] Event 176: 237 peaks heights(237 from t = 0 to 100000000.0 ns).
# [CH4] Event 181: 230 peaks heights(230 from t = 0 to 100000000.0 ns).
# [CH4] Event 182: 217 peaks heights(217 from t = 0 to 100000000.0 ns).
# [CH4] Event 183: 230 peaks heights(230 from t = 0 to 100000000.0 ns).
# [CH4] Received 66 delta trains
# Converting data from ns to ms for histogram plot.

# %%
from socketudp.extinction_functions import fft

fft_range = (0e6, 40e6)
ch1, fft_range_1 = get_delta_train(1, fft_range)
# ch1 = np.array([])  # use if ch1 is just the trigger pulse
print()
ch2, fft_range_2 = get_delta_train(2, fft_range)
print()
ch3, fft_range_3 = get_delta_train(3, fft_range)
print()

chs: list[np.ndarray] = []
total_fft_range: tuple[float, float] | tuple[float, float] = (np.inf, -np.inf)
for ch in [ch1, ch2, ch3]:
    if ch.size > 0:
        chs.append(ch)
        # recalculate total min/max range with new ch
        total_fft_range = (min(total_fft_range[0], min(ch)), max(total_fft_range[1], max(ch)))

# Run three FFTs / calculate average period
periods: list[float] = []
period_errors: list[float] = []
delta_trains: list[np.ndarray] = []

for i in range(len(chs)):
    r = fft(i+1,
            chs[i],
            fft_time_range_ns = (total_fft_range[0], total_fft_range[1]),
            expected_peak_khz=590,
            sample_rate=sample_rate, desired_f_resolution=desired_f_resolution, hc=hc,
            signal_period=signal_period, length_ns=length_ns, common_title_text=common_title_text, zero_padding_ratio=zero_padding_ratio)
    delta_trains.append(r[0])
    periods.append(r[1])
    period_errors.append(r[2])
    print()

# ##########
# COMBINE PERIODS
# ##########
if not any(periods):
    raise Exception("No periods found")
period = float(np.mean(periods))
period_error = np.std(periods) / np.sqrt(len(periods))
print(f"Averaged Period: {period:.6f} ns, Error: {period_error:.6f} ns (std.dev error)")

weighted_period, final_error = combine_periods(period, periods, period_errors)
# Out:
# [CH1] Using real data from channel 1 with 12 events.
# [CH1] First event time: 445260272.00 ns,
#
# [CH2] Using real data from channel 2 with 3 events.
# [CH2] First event time: 339506560.00 ns,
# 19425924 19425924
#
# [CH3] Using real data from channel 3 with 6 events.
# [CH3] First event time: 68036852.00 ns,
# 4283032 4283032
#
# [CH1] Total time: 0.000 ms
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 26
#      23 delta_trains: list[np.ndarray] = []
#      25 for i in range(len(chs)):
# ---> 26     r = fft(i+1,
#      27             chs[i],
#      28             fft_time_range_ns = (total_fft_range[0], total_fft_range[1]),
#      29             expected_peak_khz=590,
#      30             sample_rate=sample_rate, desired_f_resolution=desired_f_resolution, hc=hc,
#      31             signal_period=signal_period, length_ns=length_ns, common_title_text=common_title_text, zero_padding_ratio=zero_padding_ratio)
#      32     delta_trains.append(r[0])
#      33     periods.append(r[1])
#
# File ~\Documents\FPGAs\mu2e_UEM_firmware\socketudp\extinction_functions.py:685, in fft(channel, delta_train, fft_time_range_ns, expected_peak_khz, use, sample_rate, desired_f_resolution, hc, signal_period, length_ns, common_title_text, zero_padding_ratio)
#     680 print(f"[CH{channel}] Total time: {length_ns * 1e-6:.3f} ms")
#     681 # to calc. minimum allowed sampling frequency, use Nyquist theorem:
#     682 # know we want to measure 1 / 1695 ns = 590.5 kHz, so we need at least 2 * 590.5 kHz = 1.181 MHz
#     683 # corresponds to a sampling time of 1 / 1.181 MHz = 846.5 ns
#     684 # anything outside of that will be aliased
# --> 685 theoretical_peak_width: float = 1 / length_ns * 1e6  # kHz, theoretical peak width in kHz
#     686 print(f"[CH{channel}] Expected theoretical peak width: {theoretical_peak_width:.4f} kHz")
#     688 # start creating bins
#
# ZeroDivisionError: division by zero

# %%
from extinction_plots import plot_1d_histogram

plot_1d_histogram(chs, common_title_text=common_title_text, hist_range=total_fft_range,
                  title=f"Full Histogram - Time Range: {total_fft_range[0] * 1e-6:.2f} to {total_fft_range[1] * 1e-6:.2f} ms",
                  fig_size=(6, 4), file_name=f"img/{hc.folder_name}/full_histogram.png", loc="upper left",
                  log=True, bin_size_ns=0.05e6, alpha=0.7)

# start = 32.5e6 - 32.5e6 % period - 500
start = 16e6
offset = 225
start = start - start % period - offset
end = start + period * 10

plot_1d_histogram(chs, common_title_text=common_title_text, include_sample_peaks=True,
                  sample_period=period, hist_range=(start, end), loc="best", alpha=0.7, bin_size_ns=40,
                  fig_size = (12, 4), sample_offset=-150,
                  file_name=f"img/{hc.folder_name}/{hc.file_name}_zoomed_1d_histogram.png",
                  title=f"Selective Zoom-In - Time Range: {start * 1e-6:.2f} to {end * 1e-6:.2f} ms",
                  units='ns')

# %% [markdown]
# ![hi](../documentation_texts/old/vladimir_beam_loss_slide_1.png)
# ![hi](../documentation_texts/old/vladimir_beam_loss_slide_2.png)

# %%
# #######################################################
# PLOT 2D HISTOGRAM
# #######################################################
from extinction_plots import plot_2d_histogram_delta_train

for channel, delta_train in enumerate(delta_trains):
    plot_2d_histogram_delta_train(delta_train, period, common_title_text=common_title_text,
                                  channel = channel + 1,
                                  # file_name=f"img/{hex_check.folder_name}/{hex_check.file_name}_2d_histogram_ch{channel+1}.svg",
                                  file_name=f"img/{hc.folder_name}/2d_histogram_uncorrected.png",
                                  bin_width_ns = 12,
                                  n_slices=40,
                                  figsize=(8, 4), colors = ['inferno'],
                                  title=f"2D Histogram (uncorrected for mean and period errors) [{channel + 1}]")

# %%
# #######################################################
# Pulse Centering
# #######################################################
from extinction_functions import center_pulses

# period = 1694.943 ... 0284359757
# new_period = 1694.933 0284359758
# new_period = period - 0.01

# normalize delta train by detected period once, but we will slightly nudge it to make it better now
normalized_delta_trains = []
for i, delta_train in enumerate(delta_trains):
    s = symmetric_mod(delta_train, period)
    print(f"[CH{i+1}] Normalized delta train mean: {s.mean():.3f} ns, ")
    normalized_delta_trains.append(s)
new_detected_period = period

# Plot histogram normalized by FFT period
plot_normalized_histogram(delta_trains, normalized_delta_trains, period, figsize=(10, 5),
                          file_name=f"img/{hc.folder_name}/{hc.file_name}_normalized_histogram.svg",
                          title=f"Period-Modulated Histogram (without mean and period corrections)", log=True)

new_delta_trains, new_period, correction_to_mean = center_pulses(delta_trains, period)
normalized_delta_trains = [symmetric_mod(delta_train, new_period) for delta_train in new_delta_trains]

common_title_text = re.sub(r' - Channel \d', '', common_title_text)  # remove channel number from title

# %%
# Plot histogram normalized by FFT period
plot_normalized_histogram(new_delta_trains, normalized_delta_trains, new_period,
                          file_name=f"img/{hc.folder_name}/{hc.file_name}_corrected_normalized_histogram.svg",
                          figsize=(10, 5), log=False, bin_count=200,
                          title = "Period-Modulated Histogram")

# Plot histogram normalized by FFT period
plot_normalized_histogram(new_delta_trains, normalized_delta_trains, new_period,
                          file_name=f"img/{hc.folder_name}/{hc.file_name}_corrected_normalized_histogram.svg",
                          figsize=(10, 5), log=True, symlog=False, bin_count=200,
                          title = "Period-Modulated Histogram")

# %%
t_range_begin_ns = 0
# t_range = (t_range_begin_ns, t_range_begin_ns + 1695*50)
t_range = (0, 100.e6)
delta_trains_per_event, fft_time_range_ns_2 = get_delta_train_per_event(channel=1,
                                                                        fft_time_range_ns=t_range)

means = []
normalized_delta_trains_per_event = []

for delta_train in delta_trains_per_event:
    d: np.ndarray = symmetric_mod(delta_train, new_period).astype(float)
    means.append(np.mean(d))

total_mean = np.mean(means)
normalized_delta_trains_per_event = [symmetric_mod(d - total_mean, new_period) for d in delta_trains_per_event]
print(f"Adjusted delta train mean by {total_mean:.3f} ns")

plot_2d_histogram_time_vs_event_number(
    normalized_delta_trains_per_event,
    bin_width = 4,
    units='ns',
    t_range = (-900, 900),
    # t_range=t_range
)

# %%
# Check this plot again after period and mean corrections
start = 15e6
start = start - start % new_period - 500
end = start + new_period * 6
plot_1d_histogram(new_delta_trains, common_title_text=common_title_text, include_sample_peaks=True,
                  sample_period=new_period, hist_range=(start, end), loc="upper right", alpha=0.7, bin_size_ns=36,
                  fig_size = (12, 4), sample_offset = 500, legend=True,
                  title=f"Selective Zoom-In - Time Range: {start * 1e-6:.3f} to {end * 1e-6:.3f} ms",
                  file_name=f"img/{hc.folder_name}/{hc.file_name}_zoomed_corrected_1d_histogram.svg",
                  units="ns")

end = start + new_period * 4.5
plot_1d_histogram(new_delta_trains, common_title_text=common_title_text, include_sample_peaks=True, sample_offset=500,
                  sample_period=new_period, hist_range=(start, end), loc="upper right", alpha=1, bin_size_ns=24,
                  fig_size=(10, 4), legend=True,
                  # file_name=f"img/{hex_check.folder_name}/zoomed_histogram.png",
                  file_name=f"img/{hc.folder_name}/MOP037_f4.png",
                  title=f"Selective Zoom-In - Time Range: {start * 1e-6:.3f} to {end * 1e-6:.3f} ms")

# %%
# #######################################################
# PLOT 2D HISTOGRAM
# #######################################################

# fig, ax = plt.subplots(1, 1, figsize=(8, 4))
#
# plot_2d_histogram_delta_train(delta_trains[2], period, common_title_text=common_title_text,
#                               channel = 3, fig_ax = (fig, ax), subplot_no = 1,
#                               colors=['Reds'], bin_width_ns = 4,
#                               n_slices=125, alpha=1,
#                               title = f"2D Histogram, before/after corrections",
#                               )
#
# plot_2d_histogram_delta_train(new_delta_trains[2], new_period, common_title_text=common_title_text,
#                               channel = 3, fig_ax = (fig, ax), subplot_no = 2,
#                               colors=['Greens'], bin_width_ns = 4,
#                               n_slices=125, alpha=0.5,
#                               )
#
# plt.tight_layout()
# plt.savefig(f"img/{hc.folder_name}/2d_hist_comparison.svg", dpi=300, bbox_inches='tight',
#             pad_inches=0)
# plt.savefig(f"img/{hc.folder_name}/MOP037_f6.png", dpi=300, bbox_inches='tight',
#             pad_inches=0)
# plt.show()

for channel, new_delta_train in enumerate(new_delta_trains):
    plot_2d_histogram_delta_train(new_delta_train, new_period, common_title_text=common_title_text,
                                  channel = channel + 1,
                                  # file_name=f"img/{hex_check.folder_name}/{hex_check.file_name}_corrected_2d_histogram_ch{channel+1}.svg",
                                  file_name=f"img/{hc.folder_name}/2d_histogram_corrected.png",
                                  colors=['inferno'],
                                  n_slices=40,
                                  figsize=(10, 8),
                                  title=f"2D Histogram (Channel {channel + 1})",
                                  )

all_trains = []
all_trains = np.concatenate(new_delta_trains)  # combine all delta trains into one
plot_2d_histogram_delta_train(all_trains, new_period, common_title_text=common_title_text,
                              channel = 1,
                              # file_name=f"img/{hex_check.folder_name}/{hex_check.file_name}_corrected_2d_histogram_ch{channel+1}.svg",
                              file_name=f"img/{hc.folder_name}/2d_histogram_corrected.png",
                              colors=['Blues'],
                              n_slices=125, bin_width_ns=4,
                              figsize=(8, 4),
                              title="2D Histogram (All Channels Combined)",
                              )

# %%
from socketudp.extinction_plots import plot_2d_histogram_delta_train_compare
#
# fig, ax = plt.subplots(1, 1, figsize=(9.5, 4))
# plot_2d_histogram_delta_train_compare(
#     before_delta=delta_trains[2],
#     after_delta=new_delta_trains[2],
#     before_period_ns=period,
#     after_period_ns=new_period,      # or period; both are fine as long as one is used for binning
#     common_title_text=common_title_text,
#     fig_ax=(fig, ax),
#     bin_width_ns=4,
#     n_slices=125,
#     mode="ratio",                         # "diff" or "ratio"
#     title="2D Histogram: after – before (Δcounts)",
# )
# plt.tight_layout()
# plt.savefig(f"img/{hc.folder_name}/2d_hist_comparison.svg", dpi=300, bbox_inches='tight', pad_inches=0)
# plt.savefig(f"img/{hc.folder_name}/MOP037_f6.png", dpi=300, bbox_inches='tight', pad_inches=0)
# plt.show()

# %%
# #######################################################
# EXTINCTION MEASUREMENT
# #######################################################

for i, normalized_delta_train in enumerate(normalized_delta_trains):
    # define +/- 125 ns window as "in-time", and everything else as "out-of-time"
    in_time_counts = np.sum(np.abs(normalized_delta_train) <= 125)
    out_of_time_counts = len(normalized_delta_train) - in_time_counts
    print(f"[CH{i+1}] In-time counts: {in_time_counts}, Out-of-time counts: {out_of_time_counts}")
    extinction_ratio = out_of_time_counts / (in_time_counts + out_of_time_counts)
    print(f"[CH{i+1}] Extinction ratio: {extinction_ratio:.3e} (out-of-time / total counts)")

# %%
# ############################
# THREE FOLD COINCIDENCE
# ############################

average_points = get_three_fold_coincidence_points(new_delta_trains,
                                                   coincidence_window_ns=300)

# average points is now a simple list of timestamps, plot on a histogram
if average_points.size > 0:
    three_fold_title = re.sub(r"\nTime Range: .*? ms", "", common_title_text)
    plt.figure(figsize=(10, 5))
    plt.hist(average_points / 1e6, bins=100, color='purple', alpha=0.7)
    plt.xlabel("Time (ms)")
    plt.ylabel("Counts")
    plt.title("Three-Fold Coincidence Histogram")
    plt.tight_layout()
    plt.show()

    # ------------------------------------------------------------

    fig, ax = plt.subplots(2, 1, figsize=(6, 8))

    # Plot two-part combined 2D histogram with disjointed time-axis in same figure
    plot_2d_histogram_delta_train(average_points, new_period, fig_ax = (fig, ax[1]), subplot_no = 2,
                                  common_title_text="Three-Fold Coincidence Events)",
                                  colors=['inferno'],
                                  file_name=f"img/{hc.folder_name}/{hc.file_name}_three_fold_coincidence_2d_histogram.svg", n_slices=120,
                                  figsize=(6, 8), textbox=True, t_range=(0, 2e9))

    plot_2d_histogram_delta_train(average_points, new_period, fig_ax = (fig, ax[0]), subplot_no = 1,
                                  common_title_text="Three-Fold Coincidence Events",
                                  colors=['inferno'], file_name=f"img/{hc.folder_name}/{hc.file_name}_three_fold_coincidence_2d_histogram.svg", n_slices=120,
                                  figsize=(6, 8), textbox=True, t_range=(13.5e6, np.inf))

    file_name = f"img/{hc.folder_name}/{hc.file_name}_three_fold_coincidence_2d_histogram_combined.svg"
    if file_name:
        plt.savefig(file_name, dpi=300)
    plt.show()

    # ------------------------------------------------------------------
    # plot individual histograms of chosen times
    plot_2d_histogram_delta_train(average_points, new_period,
                                  common_title_text="Three-Fold Coincidence Events",
                                  colors=['inferno'],
                                  # file_name=f"img/{hex_check.folder_name}/{hex_check.file_name}_three_fold_coincidence_2d_histogram.svg",
                                  n_slices=80,
                                  figsize=(10, 6), textbox=True, t_range=(0, 2e6))
    plot_2d_histogram_delta_train(average_points, new_period,
                              common_title_text="Three-Fold Coincidence Events",
                              colors=['inferno'], n_slices=120,
                              figsize=(8, 4), textbox=True, t_range=(13.5e6, np.inf))

# %%
# modulated version of three-fold coincidence plot

for i in range(4):
    delta_trains_per_event, fft_time_range_ns_2 = get_delta_train_per_event(channel=i+1,
                                                                            fft_time_range_ns=(5e6, 100e6),
                                                                            period=period)
    print(f"[CH{i+1}] Received {len(delta_trains_per_event)} delta trains")

    # skip if no data
    if len(delta_trains_per_event) == 0:
        continue

    # subtract mean out
    means = []
    for i in delta_trains_per_event:
        if len(i) == 0:
            continue
        means.append(np.mean(i))

    total_mean = np.mean(means)
    new_delta_trains_per_event = []
    for i in delta_trains_per_event:
        new_delta_trains_per_event.append(symmetric_mod(np.array(i) - total_mean, period))


    plot_2d_histogram_time_vs_event_number(
        new_delta_trains_per_event,
        bin_width = 10,
        units='ns',
        t_range=(-900, 900),
        binrange=(-900, 900)
    )
